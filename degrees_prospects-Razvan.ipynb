# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
print(os.getcwd())
#now cleaning the region data
 
df_region= pd.read_csv(r'./Resources/salaries-by-region.csv') 
df_region ['Starting Median Salary'] = df_region ['Starting Median Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_region ['Starting Median Salary'] = df_region ['Starting Median Salary'].astype(float)


df_region ['Mid-Career Median Salary'] = df_region ['Mid-Career Median Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_region['Mid-Career Median Salary'] = df_region ['Mid-Career Median Salary'].astype(float)

df_region['Mid-Career 10th Percentile Salary'] = df_region ['Mid-Career 10th Percentile Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_region ['Mid-Career 10th Percentile Salary'] = df_region ['Mid-Career 10th Percentile Salary'].astype(float)



df_region['Mid-Career 25th Percentile Salary'] = df_region ['Mid-Career 25th Percentile Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_region ['Mid-Career 25th Percentile Salary'] = df_region ['Mid-Career 25th Percentile Salary'].astype(float)

df_region['Mid-Career 75th Percentile Salary'] = df_region ['Mid-Career 75th Percentile Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_region ['Mid-Career 75th Percentile Salary'] = df_region ['Mid-Career 75th Percentile Salary'].astype(float)
  
df_region ['Mid-Career 90th Percentile Salary'] = df_region['Mid-Career 90th Percentile Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_region ['Mid-Career 90th Percentile Salary'] = df_region ['Mid-Career 90th Percentile Salary'].astype(float)
                                                            
                                                                         
print(df_region.head())
# Out:
# /Users/razvan/Desktop/group-3
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#    Starting Median Salary  Mid-Career Median Salary  \
# 0                 70400.0                  129000.0
# 1                 75500.0                  123000.0
# 2                 71800.0                  122000.0
# 3                 59900.0                  112000.0
# 4                 51900.0                  105000.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                          6840000.0                            93100.0
# 1                                NaN                           104000.0
# ...

# %%
df_region_pd=pd.DataFrame(df_region)
df_region_pd.head()
# Out:
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#    Starting Median Salary  Mid-Career Median Salary  \
# 0                 70400.0                  129000.0
# 1                 75500.0                  123000.0
# 2                 71800.0                  122000.0
# 3                 59900.0                  112000.0
# 4                 51900.0                  105000.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                          6840000.0                            93100.0
# 1                                NaN                           104000.0
# 2                                NaN                            96000.0
# ...

# %%
mean_salary_region_start= df_region_pd["Starting Median Salary"].mean()
mean_salary_region_start
# Out:
# 46253.4375

# %%
mean_salary_region_middle= df_region_pd["Mid-Career Median Salary"].mean()
mean_salary_region_middle
# Out:
# 83934.375

# %%
mean_salary_region_top = df_region_pd["Mid-Career 90th Percentile Salary"].mean()
mean_salary_region_top
# Out:
# 160442.12454212454

# %%
plt.bar(df_region_pd["Region"],df_region_pd["Mid-Career Median Salary"])
plt.xlabel("Region")
plt.ylabel("Mid-Career Median Salary")
plt.title("Mid-Career Median Salary by region per annum ($) - figure 1")
plt.show()
plt.savefig("./Resources/Mid-Career Median Salary by region per annum.jpg")

# %%
plt.bar(df_region_pd["Region"],df_region_pd["Starting Median Salary"])
plt.xlabel("Region")
plt.ylabel("Starting Median Salary")
plt.title("Starting Median Salary by region per annum ($) - figure 2")
plt.savefig("./Resources/Starting Median Salary by region per annum.jpg")
plt.show()

# %%
plt.bar(df_region_pd["Region"],df_region_pd["Mid-Career 90th Percentile Salary"])
plt.xlabel("Region")
plt.ylabel("Mid-Career 90th Percentile Salary")
plt.title("Mid-Career 90th Percentile Salary by region per annum ($) - figure 3")
plt.savefig("./Resources/Mid-Career 90th Percentile Salary.jpg")
plt.show()

# %% [markdown]
# Observations based on the graph analysis
#  -

# %% [markdown]
# I put California as a distinct region because there are important universities there, such as Stanford, UCLA, etc that could rival the Ivy schools found in the Northeastern region.
# When I do that, the region California is second to the Northern region, which is to be expected, on all field plotted based on the career progression salary (starting point, middle or top 10%):
#
# As it can be seen, graduates from California universities are starting roughly with the same amount salary-wise as the graduates from Northeastern region (figure 2), followed by the universities in the Southern region, then Western region and finally the Midwestern region.
#
# As expected, when there is career progress to a middle level, the univerities from the Northern area take the top spot (mainly because of the Ivy schools) followed closely by the universities in California. Interestingly, the thrid place goes to the universities in the Midwestern, followed by the schools in the Northern side and finally the Western region. (figure 2)
#
# When it comes to career progression to the 10%, the differentiation between the Northern region and the other regions can be seen clearly(figure 3). This really shows the power of the Ivy schools. On second place are the universities in California, followed close by the schools inthe Midwest and Soutern regions. The last place belongs to the unversities in the Western region.
