# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns

# %%
print(os.getcwd())
# Out:
# /Users/lionneltembu/Desktop/Bootcamp/project1/group-3

# %%
df_degrees= pd.read_csv(r'./Resources/degrees-that-pay-back.csv')

# %%
#cleaing  the degrees data frame.
df_degrees ['Starting Median Salary'] = df_degrees ['Starting Median Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_degrees ['Starting Median Salary'] = df_degrees ['Starting Median Salary'].astype(float)

df_degrees ['Mid-Career Median Salary'] = df_degrees ['Mid-Career Median Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_degrees ['Mid-Career Median Salary'] = df_degrees ['Mid-Career Median Salary'].astype(float)

df_degrees ['Mid-Career 10th Percentile Salary'] = df_degrees ['Mid-Career 10th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_degrees ['Mid-Career 10th Percentile Salary'] = df_degrees ['Mid-Career 10th Percentile Salary'].astype(float)

df_degrees ['Mid-Career 25th Percentile Salary'] = df_degrees ['Mid-Career 25th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_degrees ['Mid-Career 25th Percentile Salary'] = df_degrees ['Mid-Career 25th Percentile Salary'].astype(float)

df_degrees ['Mid-Career 75th Percentile Salary'] = df_degrees ['Mid-Career 75th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_degrees ['Mid-Career 75th Percentile Salary'] = df_degrees ['Mid-Career 75th Percentile Salary'].astype(float)

df_degrees['Mid-Career 90th Percentile Salary'] = df_degrees['Mid-Career 90th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_degrees['Mid-Career 90th Percentile Salary'] = df_degrees['Mid-Career 90th Percentile Salary'].astype(float)

print(df_degrees.head())
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting               4600000.0                 7710000.0
# 1  Aerospace Engineering               5770000.0                10100000.0
# 2            Agriculture               4260000.0                 7190000.0
# 3           Anthropology               3680000.0                 6150000.0
# 4           Architecture               4160000.0                 7680000.0
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#    Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                          4220000.0                          5610000.0
# ...

# %%
#now cleaing the college data frame .
df_college= pd.read_csv(r'./Resources/salaries-by-college-type.csv')

df_college ['Starting Median Salary'] = df_college ['Starting Median Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_college ['Starting Median Salary'] = df_college ['Starting Median Salary'].astype(float)


df_college ['Mid-Career Median Salary'] = df_college ['Mid-Career Median Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_college ['Mid-Career Median Salary'] = df_college ['Mid-Career Median Salary'].astype(float)


df_college ['Mid-Career 10th Percentile Salary'] = df_college ['Mid-Career 10th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_college ['Mid-Career 10th Percentile Salary'] = df_college ['Mid-Career 10th Percentile Salary'].astype(float)

df_college ['Mid-Career 25th Percentile Salary'] = df_college ['Mid-Career 25th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_college ['Mid-Career 25th Percentile Salary'] = df_college ['Mid-Career 25th Percentile Salary'].astype(float)
            
            
            
df_college ['Mid-Career 75th Percentile Salary'] = df_college ['Mid-Career 75th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_college ['Mid-Career 75th Percentile Salary'] = df_college ['Mid-Career 75th Percentile Salary'].astype(float)
            

df_college ['Mid-Career 90th Percentile Salary'] = df_college ['Mid-Career 90th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_college ['Mid-Career 90th Percentile Salary'] = df_college ['Mid-Career 90th Percentile Salary'].astype(float)

print(df_college.head())
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#    Starting Median Salary  Mid-Career Median Salary  \
# 0               7220000.0                12600000.0
# 1               7550000.0                12300000.0
# 2               7180000.0                12200000.0
# 3               6240000.0                11400000.0
# 4               6220000.0                11400000.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                          7680000.0                          9920000.0
# 1                                NaN                         10400000.0
# ...

# %%
df_region= pd.read_csv(r'./Resources/salaries-by-region.csv') 
df_region ['Starting Median Salary'] = df_region ['Starting Median Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_region ['Starting Median Salary'] = df_region ['Starting Median Salary'].astype(float)


df_region ['Mid-Career Median Salary'] = df_region ['Mid-Career Median Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_region['Mid-Career Median Salary'] = df_region ['Mid-Career Median Salary'].astype(float)

df_region['Mid-Career 10th Percentile Salary'] = df_region ['Mid-Career 10th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_region ['Mid-Career 10th Percentile Salary'] = df_region ['Mid-Career 10th Percentile Salary'].astype(float)



df_region['Mid-Career 25th Percentile Salary'] = df_region ['Mid-Career 25th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_region ['Mid-Career 25th Percentile Salary'] = df_region ['Mid-Career 25th Percentile Salary'].astype(float)

df_region['Mid-Career 75th Percentile Salary'] = df_region ['Mid-Career 75th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_region ['Mid-Career 75th Percentile Salary'] = df_region ['Mid-Career 75th Percentile Salary'].astype(float)
  
df_region ['Mid-Career 90th Percentile Salary'] = df_region['Mid-Career 90th Percentile Salary'].str.replace(',', '').str.replace('.', '').str.replace('$', '')
df_region ['Mid-Career 90th Percentile Salary'] = df_region ['Mid-Career 90th Percentile Salary'].astype(float)


print(df_region.head())
# Out:
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#    Starting Median Salary  Mid-Career Median Salary  \
# 0               7040000.0                12900000.0
# 1               7550000.0                12300000.0
# 2               7180000.0                12200000.0
# 3               5990000.0                11200000.0
# 4               5190000.0                10500000.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                          6840000.0                          9310000.0
# 1                                NaN                         10400000.0
# 2                                NaN                          9600000.0
# ...

# %%
df_degrees.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting               4600000.0                 7710000.0
# 1  Aerospace Engineering               5770000.0                10100000.0
# 2            Agriculture               4260000.0                 7190000.0
# 3           Anthropology               3680000.0                 6150000.0
# 4           Architecture               4160000.0                 7680000.0
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#    Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                          4220000.0                          5610000.0
# ...

# %%
df_degrees.describe()
# Out:
#        Starting Median Salary  Mid-Career Median Salary  \
# count            5.000000e+01              5.000000e+01
# mean             4.431000e+06              7.478600e+06
# std              9.360866e+05              1.608840e+06
# min              3.400000e+06              5.200000e+06
# 25%              3.705000e+06              6.082500e+06
# 50%              4.085000e+06              7.200000e+06
# 75%              4.987500e+06              8.875000e+06
# max              7.430000e+06              1.070000e+07
#
#        Percent change from Starting to Mid-Career Salary  \
# count                                          50.000000
# mean                                           69.274000
# std                                            17.909908
# min                                            23.400000
# 25%                                            59.125000
# 50%                                            67.800000
# ...

# %% [markdown]
# ## Here are some insights we can draw
#
# a. The mean starting salary for all graduates regardless of major is 44,310 USD.
#
# b. The degree with the highest mean starting salary earns 74,300 USD, while the degree with the lowest mean starting salary earns 34,000 USD.
#
# c. The mean mid-career salary for all college graduates regardless of major is 74,786 USD.
#
# d. The degree with the highest mean mid-career salary earns 107,000 USD, while the major with the lowest mean mid-career salary earns 52,000 USD.

# %%
# Rename cols.
df_degrees.columns = ['Undergraduate_Major', 'Starting_Salary', 'MidCareer_Salary', 'PercentChange_Start-MidCareer_Salary', 'Mid-Career_10%',
            'MidCareer_25%', 'Mid-Career_75%', 'Mid-Career_90%']

df_degrees.head()
# Out:
#      Undergraduate_Major  Starting_Salary  MidCareer_Salary  \
# 0             Accounting        4600000.0         7710000.0
# 1  Aerospace Engineering        5770000.0        10100000.0
# 2            Agriculture        4260000.0         7190000.0
# 3           Anthropology        3680000.0         6150000.0
# 4           Architecture        4160000.0         7680000.0
#
#    PercentChange_Start-MidCareer_Salary  Mid-Career_10%  MidCareer_25%  \
# 0                                  67.6       4220000.0      5610000.0
# 1                                  75.0       6430000.0      8210000.0
# 2                                  68.8       3630000.0      5210000.0
# 3                                  67.1       3380000.0      4550000.0
# 4                                  84.6       5060000.0      6220000.0
#
#    Mid-Career_75%  Mid-Career_90%
# 0      10800000.0      15200000.0
# 1      12700000.0      16100000.0
# 2       9630000.0      15000000.0
# 3       8930000.0      13800000.0
# ...

# %%
# Top 5 starting salaries.
df_degrees.sort_values('Starting_Salary', ascending = False).head()
# Out:
#        Undergraduate_Major  Starting_Salary  MidCareer_Salary  \
# 43     Physician Assistant        7430000.0         9170000.0
# 8     Chemical Engineering        6320000.0        10700000.0
# 12    Computer Engineering        6140000.0        10500000.0
# 19  Electrical Engineering        6090000.0        10300000.0
# 38  Mechanical Engineering        5790000.0         9360000.0
#
#     PercentChange_Start-MidCareer_Salary  Mid-Career_10%  MidCareer_25%  \
# 43                                  23.4       6640000.0      7520000.0
# 8                                   69.3       7190000.0      8730000.0
# 12                                  71.0       6610000.0      8410000.0
# 19                                  69.1       6930000.0      8380000.0
# 38                                  61.7       6370000.0      7620000.0
#
#     Mid-Career_75%  Mid-Career_90%
# 43      10800000.0      12400000.0
# 8       14300000.0      19400000.0
# 12      13500000.0      16200000.0
# ...

# %%
# Bottom 5 starting salaries.
df_degrees.sort_values('Starting_Salary').head()
# Out:
#    Undergraduate_Major  Starting_Salary  MidCareer_Salary  \
# 49             Spanish        3400000.0         5310000.0
# 47            Religion        3410000.0         5200000.0
# 18           Education        3490000.0         5200000.0
# 15    Criminal Justice        3500000.0         5630000.0
# 34          Journalism        3560000.0         6670000.0
#
#     PercentChange_Start-MidCareer_Salary  Mid-Career_10%  MidCareer_25%  \
# 49                                  56.2       3100000.0      4000000.0
# 47                                  52.5       2970000.0      3650000.0
# 18                                  49.0       2930000.0      3790000.0
# 15                                  60.9       3220000.0      4160000.0
# 34                                  87.4       3840000.0      4830000.0
#
#     Mid-Career_75%  Mid-Career_90%
# 49       7680000.0       9640000.0
# 47       7090000.0       9640000.0
# 18       7340000.0      10200000.0
# 15       8070000.0      10700000.0
# ...

# %%
# Bar plot for starting salaries by degree.

plt.figure(figsize = (10, 10))
sns.barplot(x = df_degrees.sort_values('Starting_Salary', ascending = False).Starting_Salary, # Put data in descending order by start salary.
            y = df_degrees.sort_values('Starting_Salary', ascending = False).Undergraduate_Major) # Makes the graph easier to interpret.
plt.title('Mean Starting Salaries\nby College Major', fontsize = 18)
plt.xlabel('Salary (USD)', fontsize = 14)
plt.ylabel('Undergraduate_Major', fontsize = 14)
plt.grid(axis = 'x')
plt.tight_layout()
plt.savefig("Mean Starting Salaries by College Major.jpg")

# %% [markdown]
# Looking at the chart above, we now have a better understanding of what each major makes for a starting salary. We observe that somebody who studies to become a Physician Assistant earns the highest mean starting salary, at 74,000 USD, while somebody studying Spanish earns the lowest mean starting salary, at 34,000 USD.
#
# Now lets look into mid-career salaries for each major and create another visualization:

# %%
# Top 5 mid-career salaries.
df_degrees.sort_values('MidCareer_Salary', ascending = False).head()
# Out:
#        Undergraduate_Major  Starting_Salary  MidCareer_Salary  \
# 8     Chemical Engineering        6320000.0        10700000.0
# 12    Computer Engineering        6140000.0        10500000.0
# 19  Electrical Engineering        6090000.0        10300000.0
# 1    Aerospace Engineering        5770000.0        10100000.0
# 17               Economics        5010000.0         9860000.0
#
#     PercentChange_Start-MidCareer_Salary  Mid-Career_10%  MidCareer_25%  \
# 8                                   69.3       7190000.0      8730000.0
# 12                                  71.0       6610000.0      8410000.0
# 19                                  69.1       6930000.0      8380000.0
# 1                                   75.0       6430000.0      8210000.0
# 17                                  96.8       5060000.0      7060000.0
#
#     Mid-Career_75%  Mid-Career_90%
# 8       14300000.0      19400000.0
# 12      13500000.0      16200000.0
# 19      13000000.0      16800000.0
# ...

# %%
# Bottom 5 mid-career salaries.
df_degrees.sort_values('MidCareer_Salary').head()
# Out:
#    Undergraduate_Major  Starting_Salary  MidCareer_Salary  \
# 18           Education        3490000.0         5200000.0
# 47            Religion        3410000.0         5200000.0
# 49             Spanish        3400000.0         5310000.0
# 32     Interior Design        3610000.0         5320000.0
# 39               Music        3590000.0         5500000.0
#
#     PercentChange_Start-MidCareer_Salary  Mid-Career_10%  MidCareer_25%  \
# 18                                  49.0       2930000.0      3790000.0
# 47                                  52.5       2970000.0      3650000.0
# 49                                  56.2       3100000.0      4000000.0
# 32                                  47.4       3570000.0      4260000.0
# 39                                  53.2       2670000.0      4020000.0
#
#     Mid-Career_75%  Mid-Career_90%
# 18       7340000.0      10200000.0
# 47       7090000.0       9640000.0
# 49       7680000.0       9640000.0
# 32       7250000.0      10700000.0
# ...

# %%
# Bar plot for mid-career salaries by Undergraduate Major,

plt.figure(figsize = (10, 10))
sns.barplot(x = df_degrees.sort_values('MidCareer_Salary', ascending = False).MidCareer_Salary, # Put data in descending order by mid-career salary.
            y = df_degrees.sort_values('MidCareer_Salary', ascending = False).Undergraduate_Major) # Makes graph easier to interpret.
plt.title('Mean Mid-Career Salaries\nby College Major', fontsize = 18)
plt.xlabel('Salary (USD)', fontsize = 14)
plt.ylabel('Undergraduate_Major', fontsize = 14)
plt.grid(axis = 'x')
plt.tight_layout()
plt.savefig("Mean Mid-Career Salaries by College Major.jpg")

# %% [markdown]
# However, the main DataFrame is not well-suited for creating a grouped-bar plot, so we will have to create a subset DataFrame. This subset DataFrame will combine both starting and mid-career salaries, but will have a classifier column denoting each figure as "Starting" or "Mid-Career".

# %%
# First create a new df for starting salaries.
start = df_degrees.loc[:, ['Undergraduate_Major', 'Starting_Salary']].sort_values('Starting_Salary', ascending = False)
start.rename(columns = {'Starting_Salary': 'salary'}, inplace = True)

# Add salary classifier col.
classify = []
for i in range(len(start)):
    classify.append('Starting')
start['salary_type'] = classify

start.head()
# Out:
#        Undergraduate_Major     salary salary_type
# 43     Physician Assistant  7430000.0    Starting
# 8     Chemical Engineering  6320000.0    Starting
# 12    Computer Engineering  6140000.0    Starting
# 19  Electrical Engineering  6090000.0    Starting
# 38  Mechanical Engineering  5790000.0    Starting

# %%
# Then create a df for mid-career salaries.
mid = df_degrees.loc[:, ['Undergraduate_Major', 'MidCareer_Salary']]
mid.rename(columns = {'MidCareer_Salary': 'salary'}, inplace = True)

# Add salary classifier col.
classify = []
for i in range(len(mid)):
    classify.append('Mid-Career')
mid['salary_type'] = classify

mid.head()
# Out:
#      Undergraduate_Major      salary salary_type
# 0             Accounting   7710000.0  Mid-Career
# 1  Aerospace Engineering  10100000.0  Mid-Career
# 2            Agriculture   7190000.0  Mid-Career
# 3           Anthropology   6150000.0  Mid-Career
# 4           Architecture   7680000.0  Mid-Career

# %%
# Combine the two dfs to form one big df with salaries classified as either starting or mid-career.
combined = pd.concat([start, mid]).reset_index()
combined
# Out:
#     index     Undergraduate_Major     salary salary_type
# 0      43     Physician Assistant  7430000.0    Starting
# 1       8    Chemical Engineering  6320000.0    Starting
# 2      12    Computer Engineering  6140000.0    Starting
# 3      19  Electrical Engineering  6090000.0    Starting
# 4      38  Mechanical Engineering  5790000.0    Starting
# ..    ...                     ...        ...         ...
# 95     45       Political Science  7820000.0  Mid-Career
# 96     46              Psychology  6040000.0  Mid-Career
# 97     47                Religion  5200000.0  Mid-Career
# 98     48               Sociology  5820000.0  Mid-Career
# 99     49                 Spanish  5310000.0  Mid-Career
#
# [100 rows x 4 columns]

# %%
# Grouped bar plot showing mean starting salary and mean mid-career salary for each major.
plt.figure(figsize = (10, 10))
sns.barplot(x = 'salary', y = 'Undergraduate_Major', hue = 'salary_type', data = combined.sort_values(['salary_type', 'salary'], ascending = [True, False]))
plt.title('Mean Starting vs Mid-Career\nSalaries by College Major', fontsize = 18)
plt.xlabel('Salary (USD)', fontsize = 14)
plt.ylabel('Major', fontsize = 14)
plt.grid(axis = 'x')
plt.tight_layout()
plt.savefig("Mean Starting vs Mid-Career Salaries by College Major.jpg")

# %% [markdown]
# Looking at the chart above, we are now able to see the differences between various majors' mean starting and mid-career salaries. It is evident that while some majors started out with high mean salaries, they maye have later been overtaken by other majors when compared at the mid-career point.
#
# Let's make another chart to visualize percent salary growth from starting to mid-career for each major:

# %%
# Top 5 percent salary growth.
df_degrees.sort_values('PercentChange_Start-MidCareer_Salary', ascending = False).head()
# Out:
#         Undergraduate_Major  Starting_Salary  MidCareer_Salary  \
# 37                     Math        4540000.0         9240000.0
# 42               Philosophy        3990000.0         8120000.0
# 33  International Relations        4090000.0         8090000.0
# 17                Economics        5010000.0         9860000.0
# 36                Marketing        4080000.0         7960000.0
#
#     PercentChange_Start-MidCareer_Salary  Mid-Career_10%  MidCareer_25%  \
# 37                                 103.5       4520000.0      6420000.0
# 42                                 103.5       3550000.0      5280000.0
# 33                                  97.8       3820000.0      5600000.0
# 17                                  96.8       5060000.0      7060000.0
# 36                                  95.1       4210000.0      5560000.0
#
#     Mid-Career_75%  Mid-Career_90%
# 37      12800000.0      18300000.0
# 42      12700000.0      16800000.0
# 33      11100000.0      15700000.0
# ...

# %%
# Bottom 5 percent salary growth.
df_degrees.sort_values('PercentChange_Start-MidCareer_Salary').head()
# Out:
#     Undergraduate_Major  Starting_Salary  MidCareer_Salary  \
# 43  Physician Assistant        7430000.0         9170000.0
# 40              Nursing        5420000.0         6700000.0
# 41            Nutrition        3990000.0         5530000.0
# 32      Interior Design        3610000.0         5320000.0
# 18            Education        3490000.0         5200000.0
#
#     PercentChange_Start-MidCareer_Salary  Mid-Career_10%  MidCareer_25%  \
# 43                                  23.4       6640000.0      7520000.0
# 40                                  23.6       4760000.0      5640000.0
# 41                                  38.6       3390000.0      4450000.0
# 32                                  47.4       3570000.0      4260000.0
# 18                                  49.0       2930000.0      3790000.0
#
#     Mid-Career_75%  Mid-Career_90%
# 43      10800000.0      12400000.0
# 40       8090000.0       9830000.0
# 41       7050000.0       9920000.0
# ...

# %%
# Bar plot showing salary growth for each major
plt.figure(figsize = (10, 10))
sns.barplot(x = df_degrees.sort_values('PercentChange_Start-MidCareer_Salary', ascending = False)['PercentChange_Start-MidCareer_Salary'],
           y = df_degrees.sort_values('PercentChange_Start-MidCareer_Salary', ascending = False).Undergraduate_Major)
plt.title('Mean % Salary Growth\nby College Major', fontsize = 18)
plt.xlabel('Salary Growth Rate (%)', fontsize = 14)
plt.ylabel('Undergraduate_Major', fontsize = 14)
plt.grid(axis = 'x')
plt.tight_layout()
plt.savefig("Mean % Salary Growth by College Major.jpg")

# %% [markdown]
# As we can see from the chart above, people who study Math experience the highest mean salary growth rate at 103.5%, while people who study to become a Physician Assistant experience the lowest mean salary growth rate, at 23.4%.
