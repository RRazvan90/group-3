# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
print(os.getcwd())
# Out:
# C:\Users\patri\uob\Homework\project 1\group-3

# %%
df_degrees= pd.read_csv(r'../group-3/Resources/degrees-that-pay-back.csv')

# %%
#cleaing  the degrees data frame.
df_degrees ['Starting Median Salary'] = df_degrees ['Starting Median Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_degrees ['Starting Median Salary'] = df_degrees ['Starting Median Salary'].astype(float)

df_degrees ['Mid-Career Median Salary'] = df_degrees ['Mid-Career Median Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_degrees ['Mid-Career Median Salary'] = df_degrees ['Mid-Career Median Salary'].astype(float)

df_degrees ['Mid-Career 10th Percentile Salary'] = df_degrees ['Mid-Career 10th Percentile Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_degrees ['Mid-Career 10th Percentile Salary'] = df_degrees ['Mid-Career 10th Percentile Salary'].astype(float)

df_degrees ['Mid-Career 25th Percentile Salary'] = df_degrees ['Mid-Career 25th Percentile Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_degrees ['Mid-Career 25th Percentile Salary'] = df_degrees ['Mid-Career 25th Percentile Salary'].astype(float)

df_degrees ['Mid-Career 75th Percentile Salary'] = df_degrees ['Mid-Career 75th Percentile Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_degrees ['Mid-Career 75th Percentile Salary'] = df_degrees ['Mid-Career 75th Percentile Salary'].astype(float)

df_degrees['Mid-Career 90th Percentile Salary'] = df_degrees['Mid-Career 90th Percentile Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
df_degrees['Mid-Career 90th Percentile Salary'] = df_degrees['Mid-Career 90th Percentile Salary'].astype(float)
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_6072\1934616416.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_degrees ['Starting Median Salary'] = df_degrees ['Starting Median Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
# C:\Users\patri\AppData\Local\Temp\ipykernel_6072\1934616416.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_degrees ['Mid-Career Median Salary'] = df_degrees ['Mid-Career Median Salary'].str.replace(',', '').str.replace('$', '').str.replace('$', '')
# ...

# %%
df_degrees
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
#x_axis
x_axis = ["Starting Median Salary", "Mid-Career Median Salary"]

# %%
df_degrees["Undergraduate Major"]
# Out:
# 0                               Accounting
# 1                    Aerospace Engineering
# 2                              Agriculture
# 3                             Anthropology
# 4                             Architecture
# 5                              Art History
# 6                                  Biology
# 7                      Business Management
# 8                     Chemical Engineering
# 9                                Chemistry
# 10                       Civil Engineering
# 11                          Communications
# 12                    Computer Engineering
# 13                        Computer Science
# 14                            Construction
# 15                        Criminal Justice
# 16                                   Drama
# 17                               Economics
# 18                               Education
# 19                  Electrical Engineering
# 20                                 English
# 21                                    Film
# ...

# %%
pay_degrees = pd.DataFrame(df_degrees, columns=["Undergraduate Major", "Starting Median Salary",
                                                "Mid-Career Median Salary"])

# %%
pay_degrees.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0

# %%
#pay_degrees.plot(x="Undergraduate Major", y=["Starting Median Salary", "Mid-Career Median Salary"],  kind="line", figsize=(10, 10))

# %%
pay_degrees_2 = pay_degrees.copy(deep=True)
pay_degrees_2.set_index('Undergraduate Major', inplace = True)

# %%
 #pay_degrees_2.plot()

# %%
#transposed = pay_degrees_2.transpose()

#transposed

# %%
mean_salary = pay_degrees_2['Mid-Career Median Salary'].mean()
mean_salary
# Out:
# 74786.0

# %%
mean_national_salary = 54132

# %%
plt.figure(figsize=(20, 10))
threshold = mean_salary
plt.axhline(y=threshold,linewidth=1, color='red', label = "Average Degree Holder Salary", linestyle='dashed')
plt.axhline(y=mean_national_salary,linewidth=1, color='green', label = "Average National Salary", linestyle='dashed')
plt.bar(pay_degrees['Undergraduate Major'],pay_degrees['Mid-Career Median Salary'])
#ax.axhline(mean_salary, c='r')
plt.xlabel("Degree", fontsize = 15)
plt.ylabel("Mid-Career Median Salary ($)", fontsize = 15)
plt.title('Mid-Career Salary by Degree', fontsize = 15)
leg = plt.legend(loc='upper center')
plt.xticks(rotation=90, fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(20, 10))
pay_degrees_3 = pay_degrees.copy(deep=True)
pay_degrees_3 = pay_degrees_3.loc[pay_degrees_3['Mid-Career Median Salary']>mean_salary]
threshold = mean_salary
plt.axhline(y=threshold,linewidth=1, color='red', label = "Average Degree Holder Salary", linestyle='dashed')
plt.axhline(y=mean_national_salary,linewidth=1, color='green', label = "Average National Salary", linestyle='dashed')
plt.bar(pay_degrees_3['Undergraduate Major'],pay_degrees_3['Mid-Career Median Salary'], color ='lightcoral')
#ax.axhline(mean_salary, c='r', linestyle='dashed')
plt.xlabel("Degree", fontsize = 15 )
plt.ylabel("Mid-Career Median Salary ($)", fontsize = 15)
plt.title('Mid-Career Salary - Degrees that pay above average', fontsize = 15)
leg = plt.legend(loc='upper center')
plt.xticks(rotation=90, fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(20, 10))
pay_degrees_4 = pay_degrees.copy(deep=True)
pay_degrees_4 = pay_degrees_4.loc[pay_degrees_4['Mid-Career Median Salary']<mean_salary]
threshold = mean_salary
plt.axhline(y=threshold,linewidth=1, color='red', label = "Average Degree Holder Salary", linestyle='dashed')
plt.axhline(y=mean_national_salary,linewidth=1, color='green', label = "Average National Salary", linestyle='dashed')
plt.bar(pay_degrees_4['Undergraduate Major'],pay_degrees_4['Mid-Career Median Salary'], color ='violet')
#ax.axhline(mean_salary, c='r', linestyle='dashed')
plt.xlabel("Degree", fontsize = 15)
plt.ylabel("Mid-Career Median Salary ($)", fontsize = 15)
plt.title('Mid-Career Salary - Degrees that pay below average', fontsize = 15)
leg = plt.legend(loc='upper center')
plt.xticks(rotation=90, fontsize = 15)
plt.show()

# %%
pay_degrees_5 = pay_degrees.copy(deep=True)

threshold = mean_salary
#plt.axhline(y=threshold,linewidth=1, color='red', label = "Median Salary")

values = pay_degrees_5['Mid-Career Median Salary']
x = pay_degrees_5['Undergraduate Major']

above_threshold = np.maximum(values - threshold, 0)
below_threshold = np.minimum(values, threshold)

figure, ax = plt.subplots(figsize=(20, 10))
ax.bar(x, below_threshold, color = 'cornflowerblue')
ax.bar(x, above_threshold, color = 'blue', bottom = below_threshold)



ax.axhline(mean_salary, c='r', label = "Average Degree Holder Salary", linestyle='dashed')
plt.axhline(y=mean_national_salary,linewidth=1, color='green', label = "Average National Salary", linestyle='dashed')
plt.xlabel("Degree", fontsize = 15)
plt.ylabel("Mid-Career Median Salary ($)", fontsize = 15)
plt.title('Mid-Career Salary by Degree', fontsize = 15)
leg = plt.legend(loc='upper center')
plt.xticks(rotation=90, fontsize = 15)
plt.savefig(r'../group-3/Mid-Career Salary by Degree')
plt.savefig('Mid-Career Salary by Degree.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.savefig(r'../group-3/Mid-Career Salary by Degree')

# %%
df_degrees["Undergraduate Major"]
# Out:
# 0                               Accounting
# 1                    Aerospace Engineering
# 2                              Agriculture
# 3                             Anthropology
# 4                             Architecture
# 5                              Art History
# 6                                  Biology
# 7                      Business Management
# 8                     Chemical Engineering
# 9                                Chemistry
# 10                       Civil Engineering
# 11                          Communications
# 12                    Computer Engineering
# 13                        Computer Science
# 14                            Construction
# 15                        Criminal Justice
# 16                                   Drama
# 17                               Economics
# 18                               Education
# 19                  Electrical Engineering
# 20                                 English
# 21                                    Film
# ...

# %%
engineering = df_degrees.iloc[[1,8,10,12,13,14,19,30,31,35,38]]
                       
engineering
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 1                  Aerospace Engineering                 57700.0
# 8                   Chemical Engineering                 63200.0
# 10                     Civil Engineering                 53900.0
# 12                  Computer Engineering                 61400.0
# 13                      Computer Science                 55900.0
# 14                          Construction                 53700.0
# 19                Electrical Engineering                 60900.0
# 30                Industrial Engineering                 57700.0
# 31           Information Technology (IT)                 49100.0
# 35  Management Information Systems (MIS)                 49200.0
# 38                Mechanical Engineering                 57900.0
#
#     Mid-Career Median Salary  \
# 1                   101000.0
# 8                   107000.0
# 10                   90500.0
# 12                  105000.0
# 13                   95500.0
# ...

# %%
sciences = df_degrees.iloc[[2,3,6,9,17,22,23,24,25,26,37,44,46]]
sciences
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 2          Agriculture                 42600.0                   71900.0
# 3         Anthropology                 36800.0                   61500.0
# 6              Biology                 38800.0                   64800.0
# 9            Chemistry                 42600.0                   79900.0
# 17           Economics                 50100.0                   98600.0
# 22             Finance                 47900.0                   88300.0
# 23            Forestry                 39100.0                   62600.0
# 24           Geography                 41200.0                   65500.0
# 25             Geology                 43500.0                   79500.0
# 26      Graphic Design                 35700.0                   59800.0
# 37                Math                 45400.0                   92400.0
# 44             Physics                 50300.0                   97300.0
# ...

# %%
healthcare = df_degrees.iloc[[27,40,41,43]]
healthcare
# Out:
#            Undergraduate Major  Starting Median Salary  \
# 27  Health Care Administration                 38800.0
# 40                     Nursing                 54200.0
# 41                   Nutrition                 39900.0
# 43         Physician Assistant                 74300.0
#
#     Mid-Career Median Salary  \
# 27                   60600.0
# 40                   67000.0
# 41                   55300.0
# 43                   91700.0
#
#     Percent change from Starting to Mid-Career Salary  \
# 27                                               56.2
# 40                                               23.6
# 41                                               38.6
# 43                                               23.4
#
#     Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 27                            34600.0                            45600.0
# 40                            47600.0                            56400.0
# ...

# %%
arts = df_degrees.iloc[[0,5,7,11,15,16,18,20,21,28,29,32,33,34,36,39,42,45,47,48,49]]
arts
# Out:
#         Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                Accounting                 46000.0                   77100.0
# 5               Art History                 35800.0                   64900.0
# 7       Business Management                 43000.0                   72100.0
# 11           Communications                 38100.0                   70000.0
# 15         Criminal Justice                 35000.0                   56300.0
# 16                    Drama                 35900.0                   56900.0
# 18                Education                 34900.0                   52000.0
# 20                  English                 38000.0                   64700.0
# 21                     Film                 37900.0                   68500.0
# 28                  History                 39200.0                   71000.0
# 29    Hospitality & Tourism                 37800.0                   57500.0
# ...

# %%
average_engineering = engineering[["Starting Median Salary","Mid-Career Median Salary","Mid-Career 10th Percentile Salary",
                                   "Mid-Career 25th Percentile Salary","Mid-Career 75th Percentile Salary",
                                   "Mid-Career 90th Percentile Salary"]].mean()
average_engineering
# Out:
# Starting Median Salary                56418.181818
# Mid-Career Median Salary              94209.090909
# Mid-Career 10th Percentile Salary     59809.090909
# Mid-Career 25th Percentile Salary     74645.454545
# Mid-Career 75th Percentile Salary    122427.272727
# Mid-Career 90th Percentile Salary    160818.181818
# dtype: float64

# %%
average_sciences = sciences[["Starting Median Salary","Mid-Career Median Salary","Mid-Career 10th Percentile Salary",
                                   "Mid-Career 25th Percentile Salary","Mid-Career 75th Percentile Salary",
                                   "Mid-Career 90th Percentile Salary"]].mean()
average_sciences
# Out:
# Starting Median Salary                42300.000000
# Mid-Career Median Salary              75576.923077
# Mid-Career 10th Percentile Salary     41915.384615
# Mid-Career 25th Percentile Salary     55638.461538
# Mid-Career 75th Percentile Salary    104569.230769
# Mid-Career 90th Percentile Salary    151923.076923
# dtype: float64

# %%
average_healthcare = healthcare[["Starting Median Salary","Mid-Career Median Salary","Mid-Career 10th Percentile Salary",
                                   "Mid-Career 25th Percentile Salary","Mid-Career 75th Percentile Salary",
                                   "Mid-Career 90th Percentile Salary"]].mean()
average_healthcare
# Out:
# Starting Median Salary                51800.0
# Mid-Career Median Salary              68650.0
# Mid-Career 10th Percentile Salary     45625.0
# Mid-Career 25th Percentile Salary     55425.0
# Mid-Career 75th Percentile Salary     84550.0
# Mid-Career 90th Percentile Salary    105625.0
# dtype: float64

# %%
average_arts = arts[["Starting Median Salary","Mid-Career Median Salary","Mid-Career 10th Percentile Salary",
                                   "Mid-Career 25th Percentile Salary","Mid-Career 75th Percentile Salary",
                                   "Mid-Career 90th Percentile Salary"]].mean()
average_arts
# Out:
# Starting Median Salary                37914.285714
# Mid-Career Median Salary              65195.238095
# Mid-Career 10th Percentile Salary     34976.190476
# Mid-Career 25th Percentile Salary     46242.857143
# Mid-Career 75th Percentile Salary     93600.000000
# Mid-Career 90th Percentile Salary    135038.095238
# dtype: float64

# %%
starting_median = [engineering[["Starting Median Salary"]].mean(),sciences[["Starting Median Salary"]].mean(),
                   healthcare[["Starting Median Salary"]].mean(),arts[["Starting Median Salary"]].mean()]
starting_median
# Out:
# [Starting Median Salary    56418.181818
#  dtype: float64,
#  Starting Median Salary    42300.0
#  dtype: float64,
#  Starting Median Salary    51800.0
#  dtype: float64,
#  Starting Median Salary    37914.285714
#  dtype: float64]

# %%
mid_career_median = [engineering[["Mid-Career Median Salary"]].mean(),sciences[["Mid-Career Median Salary"]].mean(),
                   healthcare[["Mid-Career Median Salary"]].mean(),arts[["Mid-Career Median Salary"]].mean()]

# %%
mid_career_10th = [engineering[["Mid-Career 10th Percentile Salary"]].mean(),
                   sciences[["Mid-Career 10th Percentile Salary"]].mean(),
                   healthcare[["Mid-Career 10th Percentile Salary"]].mean(),
                   arts[["Mid-Career 10th Percentile Salary"]].mean()]

mid_career_10th
# Out:
# [Mid-Career 10th Percentile Salary    59809.090909
#  dtype: float64,
#  Mid-Career 10th Percentile Salary    41915.384615
#  dtype: float64,
#  Mid-Career 10th Percentile Salary    45625.0
#  dtype: float64,
#  Mid-Career 10th Percentile Salary    34976.190476
#  dtype: float64]

# %%
mid_career_90th = [engineering[["Mid-Career 90th Percentile Salary"]].mean(),
                   sciences[["Mid-Career 90th Percentile Salary"]].mean(),
                   healthcare[["Mid-Career 90th Percentile Salary"]].mean(),
                   arts[["Mid-Career 90th Percentile Salary"]].mean()]
mid_career_90th
# Out:
# [Mid-Career 90th Percentile Salary    160818.181818
#  dtype: float64,
#  Mid-Career 90th Percentile Salary    151923.076923
#  dtype: float64,
#  Mid-Career 90th Percentile Salary    105625.0
#  dtype: float64,
#  Mid-Career 90th Percentile Salary    135038.095238
#  dtype: float64]

# %%
data = {"Starting Median Salary":[engineering["Starting Median Salary"].mean(),sciences["Starting Median Salary"].mean(),
                   healthcare["Starting Median Salary"].mean(),arts["Starting Median Salary"].mean()],
       "Mid-Career Median Salary":[engineering["Mid-Career Median Salary"].mean(),sciences["Mid-Career Median Salary"].mean(),
                   healthcare["Mid-Career Median Salary"].mean(),arts["Mid-Career Median Salary"].mean()],
       "Mid-Career 10th Percentile Salary":[engineering["Mid-Career 10th Percentile Salary"].mean(),
                   sciences["Mid-Career 10th Percentile Salary"].mean(),
                   healthcare["Mid-Career 10th Percentile Salary"].mean(),
                   arts["Mid-Career 10th Percentile Salary"].mean()],
       "Mid-Career 90th Percentile Salary":[engineering["Mid-Career 90th Percentile Salary"].mean(),
                   sciences["Mid-Career 90th Percentile Salary"].mean(),
                   healthcare["Mid-Career 90th Percentile Salary"].mean(),
                   arts["Mid-Career 90th Percentile Salary"].mean()]}
disciplines_df = pd.DataFrame(data, index = ['Engineering',
                             'Sciences',
                             'Healthcare',
                             'Arts'])
disciplines_df
# Out:
#              Starting Median Salary  Mid-Career Median Salary  \
# Engineering            56418.181818              94209.090909
# Sciences               42300.000000              75576.923077
# Healthcare             51800.000000              68650.000000
# Arts                   37914.285714              65195.238095
#
#              Mid-Career 10th Percentile Salary  \
# Engineering                       59809.090909
# Sciences                          41915.384615
# Healthcare                        45625.000000
# Arts                              34976.190476
#
#              Mid-Career 90th Percentile Salary
# Engineering                      160818.181818
# Sciences                         151923.076923
# Healthcare                       105625.000000
# Arts                             135038.095238

# %%
f,ax=plt.subplots(figsize=(15,5))
disciplines_df.plot(ax=ax, use_index=True)
plt.show()

# %%
disciplines_df.reset_index(inplace=True)


disciplines_df
# Out:
#          index  Starting Median Salary  Mid-Career Median Salary  \
# 0  Engineering            56418.181818              94209.090909
# 1     Sciences            42300.000000              75576.923077
# 2   Healthcare            51800.000000              68650.000000
# 3         Arts            37914.285714              65195.238095
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                       59809.090909                      160818.181818
# 1                       41915.384615                      151923.076923
# 2                       45625.000000                      105625.000000
# 3                       34976.190476                      135038.095238

# %%
discipline_df_2 = disciplines_df.rename(columns = {'index':'Discipline'})

# %%
discipline_df_2
# Out:
#     Discipline  Starting Median Salary  Mid-Career Median Salary  \
# 0  Engineering            56418.181818              94209.090909
# 1     Sciences            42300.000000              75576.923077
# 2   Healthcare            51800.000000              68650.000000
# 3         Arts            37914.285714              65195.238095
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                       59809.090909                      160818.181818
# 1                       41915.384615                      151923.076923
# 2                       45625.000000                      105625.000000
# 3                       34976.190476                      135038.095238

# %%
plt.figure(figsize=(20, 10))
plt.bar(discipline_df_2['Discipline'],discipline_df_2['Starting Median Salary'], color ='coral')
#ax.axhline(mean_salary, c='r', linestyle='dashed')
plt.xlabel("Discipline", fontsize = 15)
plt.ylabel("Starting Median Salary ($)", fontsize = 15)
plt.title('Average Starting Salary per Discipline', fontsize = 15)
leg = plt.legend(loc='upper center')
plt.xticks(rotation=90, fontsize = 15)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(20, 10))
plt.bar(discipline_df_2['Discipline'],discipline_df_2['Mid-Career Median Salary'], color ='sandybrown')
#ax.axhline(mean_salary, c='r', linestyle='dashed')
plt.xlabel("Discipline", fontsize = 15)
plt.ylabel("Mid-Career Median Salary ($)", fontsize = 15)
plt.title('Average Mid-Career Salary per Discipline', fontsize = 15)
leg = plt.legend(loc='upper center')
plt.xticks(rotation=90, fontsize = 15)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(20, 10))
plt.bar(discipline_df_2['Discipline'],discipline_df_2['Mid-Career 90th Percentile Salary'], color ='red')
#ax.axhline(mean_salary, c='r', linestyle='dashed')
plt.xlabel("Discipline", fontsize = 15)
plt.ylabel("Mid-Career 90th Percentile Salary ($)", fontsize = 15)
plt.title('Mid-Career 90th Percentile Salary per Discipline', fontsize = 15)
leg = plt.legend(loc='upper center')
plt.xticks(rotation=90, fontsize = 15)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
